# %%
# ============================================================
# Name     : VETTRI SELVAN D
# Roll No  : 24BAD127
# ============================================================

import numpy as np
import matplotlib.pyplot as plt

# Input values
x = np.linspace(-10, 10, 1000)

# Activation Functions
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

# Calculate activation values
sigmoid_y = sigmoid(x)
tanh_y = tanh(x)
relu_y = relu(x)

# Plotting Activation Functions
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.plot(x, sigmoid_y, label="Sigmoid")
plt.title("Sigmoid Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(x, tanh_y, label="Tanh")
plt.title("Tanh Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(x, relu_y, label="ReLU")
plt.title("ReLU Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# Combined Comparison Plot
plt.figure(figsize=(10, 6))

plt.plot(x, sigmoid_y, label="Sigmoid")
plt.plot(x, tanh_y, label="Tanh")
plt.plot(x, relu_y, label="ReLU")

plt.title("Comparison of Activation Functions")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.legend()

plt.show()

# %%
# ============================================================
# TASK B: PERFORMANCE COMPARISON OF ACTIVATION FUNCTIONS
# Name     : VETTRI SELVAN D
# Roll No  : 24BAD127
# ============================================================

import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize the dataset
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Build ANN model
def create_model(activation):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation=activation),
        tf.keras.layers.Dense(64, activation=activation),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# Activation functions to compare
activations = ["sigmoid", "tanh", "relu"]

# Store training histories
histories = {}

# Store comparison results
results = []

# Train models
for activation in activations:

    print("\nTraining model using:", activation.upper())

    model = create_model(activation)

    history = model.fit(
        x_train,
        y_train,
        validation_data=(x_test, y_test),
        epochs=10,
        batch_size=128,
        verbose=1
    )

    histories[activation] = history

    train_accuracy = history.history["accuracy"][-1]
    val_accuracy = history.history["val_accuracy"][-1]
    train_loss = history.history["loss"][-1]
    val_loss = history.history["val_loss"][-1]

    # Calculate convergence epoch
    best_accuracy = max(history.history["val_accuracy"])
    convergence_epoch = history.history["val_accuracy"].index(best_accuracy) + 1

    results.append([
        activation.upper(),
        train_accuracy,
        val_accuracy,
        train_loss,
        val_loss,
        convergence_epoch
    ])

# Create comparison table
comparison = pd.DataFrame(
    results,
    columns=[
        "Activation Function",
        "Training Accuracy",
        "Validation Accuracy",
        "Training Loss",
        "Validation Loss",
        "Epoch of Best Validation Accuracy"
    ]
)

print("\nACTIVATION FUNCTION PERFORMANCE COMPARISON")
print(comparison.to_string(index=False))

# Accuracy Comparison
plt.figure(figsize=(10, 6))

for activation in activations:
    plt.plot(
        histories[activation].history["accuracy"],
        label=activation.upper() + " Training"
    )
    plt.plot(
        histories[activation].history["val_accuracy"],
        linestyle="--",
        label=activation.upper() + " Validation"
    )

plt.title("Training and Validation Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# Loss Comparison
plt.figure(figsize=(10, 6))

for activation in activations:
    plt.plot(
        histories[activation].history["loss"],
        label=activation.upper() + " Training"
    )
    plt.plot(
        histories[activation].history["val_loss"],
        linestyle="--",
        label=activation.upper() + " Validation"
    )

plt.title("Training and Validation Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# Identify best activation function
best_model = comparison.loc[
    comparison["Validation Accuracy"].idxmax()
]

print("\nBEST ACTIVATION FUNCTION")
print("Activation Function:", best_model["Activation Function"])
print("Validation Accuracy:", round(best_model["Validation Accuracy"] * 100, 2), "%")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#
# Training model using: SIGMOID
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8170 - loss: 0.7883 - val_accuracy: 0.9141 - val_loss: 0.3228
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9242 - loss: 0.2699 - val_accuracy: 0.9357 - val_loss: 0.2238
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9421 - loss: 0.2012 - val_accuracy: 0.9470 - val_loss: 0.1782
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9540 - loss: 0.1600 - val_accuracy: 0.9548 - val_loss: 0.1479
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9613 - loss: 0.1314 - val_accuracy: 0.9622 - val_loss: 0.1264
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9686 - loss: 0.1095 - val_accuracy: 0.9648 - val_loss: 0.1132
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9735 - loss: 0.0927 - val_accuracy: 0.9693 - val_loss: 0.1030
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9768 - loss: 0.0792 - val_accuracy: 0.9716 - val_loss: 0.0939
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9805 - loss: 0.0685 - val_accuracy: 0.9734 - val_loss: 0.0875
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9831 - loss: 0.0594 - val_accuracy: 0.9739 - val_loss: 0.0843
#
# Training model using: TANH
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9033 - loss: 0.3381 - val_accuracy: 0.9404 - val_loss: 0.1993
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9522 - loss: 0.1625 - val_accuracy: 0.9552 - val_loss: 0.1456
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9673 - loss: 0.1121 - val_accuracy: 0.9675 - val_loss: 0.1085
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9754 - loss: 0.0835 - val_accuracy: 0.9711 - val_loss: 0.0944
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9807 - loss: 0.0656 - val_accuracy: 0.9741 - val_loss: 0.0846
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9851 - loss: 0.0509 - val_accuracy: 0.9747 - val_loss: 0.0819
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9880 - loss: 0.0411 - val_accuracy: 0.9758 - val_loss: 0.0766
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9912 - loss: 0.0317 - val_accuracy: 0.9764 - val_loss: 0.0805
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9927 - loss: 0.0265 - val_accuracy: 0.9782 - val_loss: 0.0761
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9950 - loss: 0.0197 - val_accuracy: 0.9770 - val_loss: 0.0799
#
# Training model using: RELU
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9061 - loss: 0.3336 - val_accuracy: 0.9521 - val_loss: 0.1598
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9607 - loss: 0.1347 - val_accuracy: 0.9627 - val_loss: 0.1203
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9719 - loss: 0.0936 - val_accuracy: 0.9719 - val_loss: 0.0937
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9783 - loss: 0.0713 - val_accuracy: 0.9730 - val_loss: 0.0829
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9825 - loss: 0.0572 - val_accuracy: 0.9733 - val_loss: 0.0818
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9852 - loss: 0.0466 - val_accuracy: 0.9736 - val_loss: 0.0805
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9884 - loss: 0.0363 - val_accuracy: 0.9774 - val_loss: 0.0770
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9901 - loss: 0.0309 - val_accuracy: 0.9767 - val_loss: 0.0807
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9917 - loss: 0.0264 - val_accuracy: 0.9772 - val_loss: 0.0781
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9937 - loss: 0.0201 - val_accuracy: 0.9768 - val_loss: 0.0807
#
# ACTIVATION FUNCTION PERFORMANCE COMPARISON
# Activation Function  Training Accuracy  Validation Accuracy  Training Loss  Validation Loss  Epoch of Best Validation Accuracy
#             SIGMOID           0.983117               0.9739       0.059417         0.084322                                 10
#                TANH           0.994967               0.9770       0.019688         0.079940                                  9
#                RELU           0.993667               0.9768       0.020111         0.080736                                  7
# BEST ACTIVATION FUNCTION
# Activation Function: TANH
# Validation Accuracy: 97.7 %

# %%
# ============================================================
# TASK C: COMPARISON OF OPTIMIZATION ALGORITHMS
# Name     : VETTRI SELVAN D
# Roll No  : 24BAD127
# ============================================================

import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize the dataset
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Build ANN model
def create_model(optimizer):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# Optimizers to compare
optimizers = {
    "SGD": tf.keras.optimizers.SGD(learning_rate=0.01),

    "Momentum": tf.keras.optimizers.SGD(
        learning_rate=0.01,
        momentum=0.9
    ),

    "RMSprop": tf.keras.optimizers.RMSprop(
        learning_rate=0.001
    ),

    "Adam": tf.keras.optimizers.Adam(
        learning_rate=0.001
    )
}

# Store histories and results
histories = {}
results = []

# Train models using different optimizers
for name, optimizer in optimizers.items():

    print("\nTraining model using:", name)

    model = create_model(optimizer)

    history = model.fit(
        x_train,
        y_train,
        validation_data=(x_test, y_test),
        epochs=10,
        batch_size=128,
        verbose=1
    )

    histories[name] = history

    train_accuracy = history.history["accuracy"][-1]
    val_accuracy = history.history["val_accuracy"][-1]
    train_loss = history.history["loss"][-1]
    val_loss = history.history["val_loss"][-1]

    # Find epoch with best validation accuracy
    best_accuracy = max(history.history["val_accuracy"])
    convergence_epoch = history.history["val_accuracy"].index(
        best_accuracy
    ) + 1

    results.append([
        name,
        train_loss,
        val_loss,
        train_accuracy,
        val_accuracy,
        convergence_epoch
    ])

# Create comparison table
comparison = pd.DataFrame(
    results,
    columns=[
        "Optimizer",
        "Training Loss",
        "Validation Loss",
        "Training Accuracy",
        "Validation Accuracy",
        "Best Accuracy Epoch"
    ]
)

print("\nOPTIMIZER PERFORMANCE COMPARISON")
print(comparison.to_string(index=False))

# Loss vs Epoch
plt.figure(figsize=(10, 6))

for name in optimizers.keys():
    plt.plot(
        histories[name].history["loss"],
        label=name + " Training"
    )

    plt.plot(
        histories[name].history["val_loss"],
        linestyle="--",
        label=name + " Validation"
    )

plt.title("Loss vs Epoch for Different Optimizers")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# Accuracy vs Epoch
plt.figure(figsize=(10, 6))

for name in optimizers.keys():
    plt.plot(
        histories[name].history["accuracy"],
        label=name + " Training"
    )

    plt.plot(
        histories[name].history["val_accuracy"],
        linestyle="--",
        label=name + " Validation"
    )

plt.title("Accuracy vs Epoch for Different Optimizers")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# Identify the optimizer with best validation accuracy
best_optimizer = comparison.loc[
    comparison["Validation Accuracy"].idxmax()
]

print("\nBEST OPTIMIZER")
print("Optimizer:", best_optimizer["Optimizer"])
print(
    "Validation Accuracy:",
    round(best_optimizer["Validation Accuracy"] * 100, 2),
    "%"
)
print(
    "Best Accuracy Achieved at Epoch:",
    int(best_optimizer["Best Accuracy Epoch"])
)
# Out:
# Training model using: SGD
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6587 - loss: 1.3334 - val_accuracy: 0.8474 - val_loss: 0.6449
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8641 - loss: 0.5239 - val_accuracy: 0.8892 - val_loss: 0.4143
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8915 - loss: 0.3961 - val_accuracy: 0.9046 - val_loss: 0.3463
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9024 - loss: 0.3460 - val_accuracy: 0.9121 - val_loss: 0.3140
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9092 - loss: 0.3167 - val_accuracy: 0.9171 - val_loss: 0.2928
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9153 - loss: 0.2955 - val_accuracy: 0.9222 - val_loss: 0.2786
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9202 - loss: 0.2791 - val_accuracy: 0.9255 - val_loss: 0.2609
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9247 - loss: 0.2646 - val_accuracy: 0.9303 - val_loss: 0.2485
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9279 - loss: 0.2520 - val_accuracy: 0.9334 - val_loss: 0.2393
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9312 - loss: 0.2411 - val_accuracy: 0.9355 - val_loss: 0.2295
#
# Training model using: Momentum
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8595 - loss: 0.4892 - val_accuracy: 0.9272 - val_loss: 0.2572
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9353 - loss: 0.2231 - val_accuracy: 0.9439 - val_loss: 0.1938
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9507 - loss: 0.1683 - val_accuracy: 0.9504 - val_loss: 0.1632
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9609 - loss: 0.1357 - val_accuracy: 0.9643 - val_loss: 0.1253
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9669 - loss: 0.1135 - val_accuracy: 0.9654 - val_loss: 0.1154
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9713 - loss: 0.0971 - val_accuracy: 0.9693 - val_loss: 0.1025
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9750 - loss: 0.0847 - val_accuracy: 0.9695 - val_loss: 0.0992
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9780 - loss: 0.0754 - val_accuracy: 0.9709 - val_loss: 0.0947
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9801 - loss: 0.0672 - val_accuracy: 0.9733 - val_loss: 0.0869
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9824 - loss: 0.0607 - val_accuracy: 0.9750 - val_loss: 0.0809
#
# Training model using: RMSprop
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9102 - loss: 0.3166 - val_accuracy: 0.9513 - val_loss: 0.1602
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9599 - loss: 0.1317 - val_accuracy: 0.9633 - val_loss: 0.1165
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9725 - loss: 0.0926 - val_accuracy: 0.9731 - val_loss: 0.0879
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9782 - loss: 0.0716 - val_accuracy: 0.9728 - val_loss: 0.0846
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9823 - loss: 0.0564 - val_accuracy: 0.9769 - val_loss: 0.0721
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9859 - loss: 0.0463 - val_accuracy: 0.9766 - val_loss: 0.0767
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9880 - loss: 0.0384 - val_accuracy: 0.9782 - val_loss: 0.0739
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9901 - loss: 0.0321 - val_accuracy: 0.9782 - val_loss: 0.0736
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9916 - loss: 0.0268 - val_accuracy: 0.9778 - val_loss: 0.0793
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9925 - loss: 0.0233 - val_accuracy: 0.9790 - val_loss: 0.0730
#
# Training model using: Adam
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9019 - loss: 0.3408 - val_accuracy: 0.9500 - val_loss: 0.1689
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9584 - loss: 0.1401 - val_accuracy: 0.9665 - val_loss: 0.1129
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9719 - loss: 0.0970 - val_accuracy: 0.9701 - val_loss: 0.0977
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9780 - loss: 0.0736 - val_accuracy: 0.9746 - val_loss: 0.0823
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9829 - loss: 0.0581 - val_accuracy: 0.9722 - val_loss: 0.0871
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9859 - loss: 0.0466 - val_accuracy: 0.9712 - val_loss: 0.0894
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9882 - loss: 0.0388 - val_accuracy: 0.9775 - val_loss: 0.0739
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9901 - loss: 0.0309 - val_accuracy: 0.9781 - val_loss: 0.0729
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9922 - loss: 0.0256 - val_accuracy: 0.9786 - val_loss: 0.0747
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9924 - loss: 0.0232 - val_accuracy: 0.9775 - val_loss: 0.0796
#
# OPTIMIZER PERFORMANCE COMPARISON
# Optimizer  Training Loss  Validation Loss  Training Accuracy  Validation Accuracy  Best Accuracy Epoch
#       SGD       0.241135         0.229457           0.931200               0.9355                   10
#  Momentum       0.060742         0.080877           0.982417               0.9750                   10
#   RMSprop       0.023341         0.072985           0.992467               0.9790                   10
#      Adam       0.023194         0.079573           0.992383               0.9775                    9
# BEST OPTIMIZER
# Optimizer: RMSprop
# Validation Accuracy: 97.9 %
# Best Accuracy Achieved at Epoch: 10

# %%
# ============================================================
# TASK D: DEEP LEARNING EXPERIMENT MANAGEMENT
# Name     : VETTRI SELVAN D
# Roll No  : 24BAD127
# ============================================================

from google.colab import drive

drive.mount('/content/drive')
# Create experiment folder
import os

folder_path = "/content/drive/MyDrive/Deep_Learning_Experiment"
os.makedirs(folder_path, exist_ok=True)

print("Experiment folder created successfully")
print("Folder location:", folder_path)

# Train and save ANN model

import tensorflow as tf

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize data
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Create ANN model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# Compile model
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Train model
model.fit(
    x_train,
    y_train,
    epochs=5,
    validation_data=(x_test, y_test)
)

# Save model to Google Drive
model_path = folder_path + "/mnist_ann_model.keras"
model.save(model_path)

print("\nModel trained successfully")
print("Model saved successfully")
print("Model location:", model_path)
# Out:
# Mounted at /content/drive
# Experiment folder created successfully
# Folder location: /content/drive/MyDrive/Deep_Learning_Experiment
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9288 - loss: 0.2428 - val_accuracy: 0.9590 - val_loss: 0.1265
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9680 - loss: 0.1040 - val_accuracy: 0.9714 - val_loss: 0.0917
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9781 - loss: 0.0714 - val_accuracy: 0.9710 - val_loss: 0.0917
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9828 - loss: 0.0552 - val_accuracy: 0.9722 - val_loss: 0.0935
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9856 - loss: 0.0442 - val_accuracy: 0.9770 - val_loss: 0.0802
#
# Model trained successfully
# Model saved successfully
# Model location: /content/drive/MyDrive/Deep_Learning_Experiment/mnist_ann_model.keras

# %%
# Verify saved model

import os

print("Files in experiment folder:")
print(os.listdir(folder_path))
# Out:
# Files in experiment folder:
# ['mnist_ann_model.keras']
